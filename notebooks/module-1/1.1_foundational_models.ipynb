# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response

# %%
print(response.content)

# %%
from pprint import pprint

pprint(response.response_metadata)

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth countries do. It's a celestial body without any permanent human settlements or governments.
#
# So, the short answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="gemini-2.5-flash-lite")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='0c0512d3-57e9-4428-baf7-b684a440150e'),
#               AIMessage(content='That\'s a fun question! The Moon doesn\'t have a capital city in the way Earth does. It\'s not a country or a political entity with governments and cities.\n\nHowever, if we were to imagine a "capital" for the Moon, based on human exploration and significant landmarks, some might jokingly or poetically suggest:\n\n*   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin first landed on July 20, 1969. It\'s the most historically significant human landing site.\n*   **A Hypothetical Future Colony:** If humans were to establish a permanent settlement, that settlement would likely become the de facto "capital."\n\nBut in reality, there\'s no official capital of the Moon!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d8b87-bdf2-7d03-86bc-17e44a04f5e2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 157, 'total_tokens': 167, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's not a country or a political entity with governments and cities.
#
# However, if we were to imagine a "capital" for the Moon, based on human exploration and significant landmarks, some might jokingly or poetically suggest:
#
# *   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin first landed on July 20, 1969. It's the most historically significant human landing site.
# *   **A Hypothetical Future Colony:** If humans were to establish a permanent settlement, that settlement would likely become the de facto "capital."
#
# But in reality, there's no official capital of the Moon!

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='43962818-2373-441f-857c-339a1c5f0e09'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='3e010e5b-b952-4632-9de7-7cdce0adbfbb', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='124e8d98-d63a-4edc-b02e-b4267eae6d61'),
#               AIMessage(content="Luna City is a fictional city on the Moon, often featured in science fiction stories and games. It's usually depicted as a hub for lunar mining, research, and space exploration. The city's design often incorporates features like domes, underground habitats, and advanced technology to cope with the Moon's harsh environment.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d8b88-2a93-74b0-8de8-78371ced67b4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 64, 'total_tokens': 93, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City, the magnificent capital of the Moon, is a testament to human ingenuity and ambition, a beacon of civilization nestled within the ethereal silence of our celestial neighbor. It's a place that sparks the imagination, a blend of advanced technology and the stark beauty of the lunar landscape.
#
# Here's a comprehensive look at what makes Luna City so extraordinary:
#
# **Location and Structure:**
#
# *   **Underground and Domed:** The primary reason for Luna City's construction is to shield its inhabitants from the harsh lunar environment. Much of the city is built **underground**, utilizing natural lava tubes and excavated caverns for structural integrity and radiation protection. Above ground, large, transparent **domes** made of advanced, reinforced polymers and reinforced glass enclose vital areas, allowing inhabitants to experience the stark beauty of the lunar surface and the breathtaking view of Earthrise.
# *   **Strategic Placement:** Luna City is strategically located in a region offering a balance of resources and geological stability. The **Sea of Tranquility** is a popular choice due to its relatively flat terrain and historical significance, but other locations might exist for specialized functions or newer settlements.
# *   **Modular and Expandable:** The city is designed with modularity in mind, allowing for continuous expansion as the population grows and new technologies emerge. Sections can be sealed off, rebuilt, or interconnected as needed.
#
# **Architecture and Design:**
#
# *   **Biomorphic and Functional:** Architecture in Luna City is a fascinating blend of the functional and the aesthetically pleasing. Structures often mimic natural forms, incorporating curves and organic shapes for structural efficiency and to counter the psychological effects of being underground.
# *   **Emphasis on Light and Space:** Despite being largely underground, Luna City prioritizes natural-feeling light. Advanced **simulated sunlight** systems mimic the Earth's diurnal cycle, and strategically placed light shafts and reflective surfaces bring in natural light from the domes. Open-plan designs and holographic projections create a sense of spaciousness.
# *   **Integrated Ecosystems:** Within the domes and larger underground caverns, meticulously engineered **biospheres** recreate Earth-like environments. Lush gardens, vertical farms, and even small parks provide oxygen, food, and a vital connection to nature for the citizens.
# *   **Material Innovation:** Construction relies on advanced materials, including **lunar regolith-based composites**, self-healing concrete, and lightweight, high-strength alloys. Water recycling and air purification systems are paramount.
#
# **Society and Culture:**
#
# *   **Diverse and Cosmopolitan:** Luna City is a melting pot of humanity, attracting individuals from all corners of Earth and beyond who are drawn by opportunity, scientific pursuit, or a desire for a new frontier. This diversity fosters a rich and dynamic culture.
# *   **Technologically Advanced:** Life in Luna City is deeply intertwined with cutting-edge technology. **AI assistants** are ubiquitous, managing daily tasks, providing information, and ensuring the smooth operation of the city. **Augmented reality** overlays are common, enhancing navigation, communication, and entertainment.
# *   **Emphasis on Sustainability and Resourcefulness:** Living in a closed system demands a strong focus on sustainability. Recycling, resource conservation, and efficient energy utilization are not just policies, but deeply ingrained cultural values.
# *   **Unique Lunar Traditions:** Over time, distinct lunar traditions and celebrations have emerged, often tied to astronomical events, the history of lunar colonization, or the unique challenges and triumphs of life off-world.
# *   **Education and Research Hub:** Luna City is a premier center for scientific research, particularly in fields like astrophysics, lunar geology, space exploration, and bio-engineering. Its educational institutions are world-renowned.
#
# **Economy:**
#
# *   **Resource Extraction:** The Moon's abundant resources, such as **Helium-3** (a potential fuel for fusion reactors), rare earth elements, and water ice, are crucial to Luna City's economy. Mining operations are extensive and highly automated.
# *   **Advanced Manufacturing:** Luna City is a hub for advanced manufacturing, utilizing its access to unique materials and its skilled workforce to produce specialized components and technologies for Earth and other space-based endeavors.
# *   **Tourism and Space Hospitality:** The allure of the Moon makes Luna City a prime destination for space tourism. Luxury hotels, observation decks, and guided excursions to lunar landmarks are significant economic drivers.
# *   **Scientific and Technological Innovation:** Investment in research and development fuels the economy, with groundbreaking discoveries and inventions constantly emerging.
# *   **Interplanetary Trade:** Luna City serves as a vital trading post for goods and services between Earth and potential future settlements on Mars or other celestial bodies.
#
# **Challenges and Considerations:**
#
# *   **Environmental Control:** Maintaining a stable and habitable environment, including air pressure, temperature, and radiation shielding, is a constant and critical challenge.
# *   **Psychological Well-being:** The long-term psychological effects of living in a confined, low-gravity environment, with limited natural light and a constant view of Earth, are actively studied and managed.
# *   **Resource Scarcity:** While the Moon has resources, efficient and sustainable management is crucial to prevent depletion.
# *   **Dependence on Earth:** Initially, and to a degree even in advanced stages, Luna City would rely on Earth for certain supplies, specialized equipment, and potentially even population replenishment.
# *   **Defense and Security:** Protecting the city from potential threats, both natural (micrometeoroids) and artificial, is a paramount concern.
#
# **Notable Landmarks (Imagined):**
#
# *   **The Earthrise Observatory:** A stunning dome offering unparalleled panoramic views of Earth rising above the lunar horizon.
# *   **The Tranquility Gardens:** A vast, biodiverse park within a massive underground cavern, featuring simulated Earth flora and fauna.
# *   **The Lunar Archives:** A state-of-the-art facility housing the collective knowledge and history of humanity, with a particular focus on space exploration.
# *   **The Helium-3 Processing Hub:** An industrial marvel showcasing the cutting-edge technology used to extract and refine this vital energy resource.
# *   **The Great Crater Amphitheater:** A naturally formed crater ingeniously adapted for cultural events and public gatherings, offering a unique acoustic experience.
#
# Luna City is more than just a city; it's a symbol of humanity's enduring spirit of exploration, innovation, and the audacious dream of making our home among the stars. It's a place where the future is being forged, one moon rock at a time.
