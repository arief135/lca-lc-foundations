# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's not a country, and there's no government or permanent population to establish one.
#
# However, if you were to imagine a "capital" in a symbolic or historical sense, you might think of:
#
# *   **Tranquility Base:** This is the site where Neil Armstrong and Buzz Aldrin first landed on the Moon during the Apollo 11 mission. It's a place of immense historical significance for humanity's exploration of space.
#
# So, while there's no official capital, **Tranquility Base** is often the place that comes to mind when thinking about a central or important location on the Moon.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the Moon, or more accurately, the primary administrative and cultural hub of Luna, is **Selenopolis**.
#
# Imagine a city not built *on* the lunar surface in the traditional sense, but rather carved *into* it. Selenopolis is a marvel of subterranean engineering, nestled within a vast, ancient lava tube network miles beneath the dusty plains of the Sea of Tranquility. This strategic location offers natural protection from radiation, micrometeoroid impacts, and the extreme temperature fluctuations of the lunar surface.
#
# **Architecture and Infrastructure:**
#
# *   **Geodesic Domes & Lumina-Gardens:** While the core of the city is subterranean, vast, crystal-clear geodesic domes punctuate the surface above key districts. These aren't just for aesthetics; they house the "Lumina-Gardens," immense hydroponic farms and biospheres that generate oxygen, purify air, and provide fresh food for the city's inhabitants. The domes are embedded with advanced solar collectors, capturing every precious ray of sunlight, and at night, they glow with a soft, bio-luminescent light, casting an ethereal aura over the surrounding regolith.
# *   **Subterranean Grandeur:** Within the lava tubes, the architecture is a blend of utilitarian functionality and breathtaking beauty. Walls are often left as the natural, polished basalt, interspersed with advanced alloys and self-healing polymers. The main thoroughfares are wide, illuminated by integrated light panels that mimic natural daylight cycles, complete with simulated dawn and dusk.
# *   **Grav-Lifts and Mag-Levs:** Transportation within Selenopolis is a silent, efficient ballet. Grav-lifts, using localized gravity manipulation, ferry citizens between different levels. For longer distances, sleek, silent mag-lev trains glide through designated tunnels, their windows offering glimpses of the subterranean landscape or projected vistas of Earth.
# *   **The Lunar Senate and the Oracle's Spire:** At the heart of Selenopolis lies the **Lunar Senate**, a grand, circular chamber carved from a particularly impressive geode. Here, representatives from the various lunar colonies and orbital stations convene. Dominating the skyline (or rather, the "cave-line") of the central district is the **Oracle's Spire**, a towering structure that houses the Central AI and the vast data archives of Luna. It's not just a data center; it's the repository of lunar history, scientific discovery, and the collective consciousness of its inhabitants.
#
# **Culture and Society:**
#
# *   **The Selenites:** The people of Selenopolis, often called "Selenites," are a diverse mix of humans and augmented beings, all adapted to low-gravity living. They are known for their pragmatism, their deep connection to science and engineering, and a quiet, introspective culture that values efficiency and communal well-being.
# *   **Art and Recreation:** Art forms often incorporate light, sound, and gravity manipulation. Holographic sculptures dance in the open plazas, and sonic gardens create immersive auditory experiences. Recreational activities include low-gravity sports like "Aero-Ball" and "Lunar Ballet," as well as exploration of the vast, uncharted sections of the lava tube networks.
# *   **The "Earth-Gaze" Tradition:** A poignant cultural ritual is the "Earth-Gaze," observed during specific lunar cycles. Citizens gather in designated viewing chambers within the Lumina-Gardens, watching the majestic blue marble of Earth hang in the black sky. It's a moment of reflection, a reminder of their origins and their unique place in the cosmos.
#
# **Challenges and Aspirations:**
#
# Selenopolis is a city built on resilience and innovation. The constant threat of resource scarcity, the psychological impact of living underground, and the ever-present need for meticulous maintenance are daily realities. However, the Selenites are driven by a profound sense of purpose: to establish a permanent, thriving civilization beyond Earth, to become a hub for interstellar exploration, and to safeguard the unique heritage of humanity's first off-world home.
#
# So, if you ever find yourself on the Moon, looking for the heart of its civilization, seek the faint glow emanating from the Sea of Tranquility, and know that beneath the silent, dusty surface lies the vibrant, subterranean metropolis of Selenopolis.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Luna City

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
#
# Location: A vast, geothermally heated cavern system beneath Mare Imbrium on Earth's Moon.
#
# Vibe: Serene, subterranean, luminous.
#
# Economy: Lunar resource extraction (helium-3, rare earth metals), advanced zero-gravity manufacturing, astronomical research, and intergalactic tourism.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selenopolis', location='Mare Imbrium', vibe='Serene, technologically advanced, with a focus on lunar resource extraction and scientific research.', economy='Lunar mining (helium-3, rare earth elements), advanced robotics manufacturing, space tourism, and scientific research.')

# %%
response["structured_response"].name
# Out:
# 'Selenopolis'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selenopolis is a city located at Mare Imbrium
