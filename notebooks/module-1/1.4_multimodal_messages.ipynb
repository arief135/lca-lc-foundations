# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Ah, the Moon! Not the dusty, silent orb of Earth's night sky, but a thriving, vibrant world in its own right. When you speak of "The Moon" as a political entity, you're referring to the unified Lunar Republic, a testament to humanity's enduring spirit and its boundless ambition.
#
# And its capital? That would be **Selenopolis**.
#
# Selenopolis isn't a city built *on* the Moon, but rather *within* it. Imagine vast, crystalline caverns, meticulously carved from the lunar regolith and reinforced with advanced, self-healing alloys. These are not dark, cramped tunnels, but immense, geothermally heated domes, each bathed in a soft, simulated daylight generated by sophisticated orbital mirrors that track the distant Sun.
#
# Here's a glimpse of what makes Selenopolis the heart of the Lunar Republic:
#
# *   **The Lumina Domes:** The core of Selenopolis is a series of interconnected, multi-tiered domes. Each dome has its own unique atmospheric composition and light spectrum, designed to foster specific biomes and industries. The "Veridian Dome" teems with genetically engineered flora, providing essential oxygen and a touch of Earth-like greenery. The "Aqua Dome" houses vast hydroponic farms and aquaculture, crucial for Lunar sustenance.
#
# *   **The Grand Observatory of Luna:** Perched on the lip of a permanently shadowed crater, this colossal structure is more than just an observatory. It's the seat of the Lunar Senate, its transparent dome offering breathtaking, unobstructed views of the cosmos and Earth, a constant reminder of their origins and their place in the universe. Within its halls, debates echo not just with the voices of senators, but with the subtle hum of sophisticated environmental controls and the whisper of recycled air.
#
# *   **The Regolith Exchange:** Selenopolis is a hub of commerce and innovation. The Regolith Exchange is a bustling, multi-level marketplace where goods mined from the Moon – Helium-3, rare earth elements, precious metals – are traded with off-world corporations. It's a place of dazzling light displays, holographic advertisements, and the murmur of a dozen Earth languages and a few nascent Lunar dialects.
#
# *   **The Sub-Crater Transit System:** Travel within Selenopolis is seamless and silent. Magnetic levitation pods glide through transparent tubes, offering panoramic views of the city's subterranean architecture. These tubes weave through the domes, connect different levels, and even extend to the outer mining outposts and orbital docks.
#
# *   **The Architects of the Void:** The citizens of Selenopolis, often referred to as "Lunarians," are a unique breed. They are descendants of the original pioneers, engineers, scientists, and dreamers who dared to make the Moon their home. They are known for their pragmatism, their deep understanding of resource management, and a quiet, almost poetic appreciation for the stark beauty of their world. Their fashion often incorporates luminescent threads and materials that subtly shift color with their mood.
#
# *   **The Echoes of Earth:** While Selenopolis is distinctly Lunar, it carries the echoes of Earth. Statues of great scientists and explorers stand in public plazas. Holographic reproductions of ancient Earth landmarks are projected onto cavern walls. And in the quieter, residential sectors, one can still find small, cherished gardens, carefully tended under the simulated sunlight, a tangible link to a world they left behind but never truly forgot.
#
# Selenopolis is more than just a capital; it's a symbol. It represents humanity's ability to adapt, to thrive in the most challenging environments, and to build a future amongst the stars. It is a city carved from silence, illuminated by ingenuity, and forever looking outward.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png,.jpg,.jpeg', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png,.jpg,.jpeg', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'mars.jpg', 'type': 'image/jpeg', 'size': 2320771, 'content': <memory at 0x112c62380>, 'last_modified': datetime.datetime(2026, 4, 14, 23, 58, 23, 871000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Welcome to **Aethelburg**, the jewel of the Martian frontier and the capital of the burgeoning Sol Federation. Nestled within the protective embrace of the Valles Marineris canyon system, Aethelburg is a testament to human ingenuity and resilience, a sprawling hexagonal city built from the ochre dust of Mars itself.
#
# From this vantage point, you can see the city's intricate design. The outermost hexagonal perimeter is lined with robust, modular habitat blocks, their segmented forms suggesting rapid expansion and adaptation. These are the homes and workshops of Aethelburg's citizens, designed to withstand the harsh Martian environment while providing comfortable living spaces.
#
# Further inward, the city's fabric becomes more complex. You can discern what appear to be industrial complexes, evidenced by the elongated, cylindrical structures that likely house resource processing facilities and power generation units. These are the lifeblood of Aethelburg, transforming Martian regolith into the materials needed for survival and growth.
#
# The central core of the city is dominated by a large, domed structure, its smooth, aerodynamic form hinting at its importance. This is likely the administrative heart of Aethelburg, perhaps housing the Council Chambers, the central AI nexus, or even a biosphere dome teeming with Earth-like flora. Smaller, interconnected domes and specialized modules radiate outwards from this central hub, suggesting research facilities, educational institutions, and public gathering spaces.
#
# Scattered throughout the city are peculiar, lattice-like structures. These could be advanced atmospheric processors, radiation shielding arrays, or even early attempts at Martian terraforming technology. Their intricate, almost organic designs speak of a society that has learned to work with, rather than against, the alien landscape.
#
# The city is not a monolithic entity; it's a carefully planned organism. The interconnectedness of its modules, the strategic placement of its industrial and residential sectors, and the clear demarcation of public and private spaces all point to a sophisticated urban planning philosophy. The city's layout suggests a focus on efficiency, safety, and the optimization of limited resources.
#
# Surrounding Aethelburg, the Martian landscape stretches out in undulating waves of sand dunes. The city is a stark contrast to its natural surroundings, a beacon of organized life against the vast, untamed wilderness. You can see tracks and small excavation sites hinting at the ongoing efforts to expand and exploit the Martian surface for resources.
#
# Aethelburg is more than just a collection of buildings; it's a symbol of humanity's reach for the stars. It's a place where scientists, engineers, miners, and dreamers have come together to forge a new future, a future written in the red dust of Mars. This is where the Sol Federation is governed, where new technologies are born, and where the next chapter of human civilization is being written.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.54it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[14], line 10
#       1 agent = create_agent(
#       2     model='gpt-4o-audio-preview',
#       3 )
#       5 multimodal_question = HumanMessage(content=[
#       6     {"type": "text", "text": "Tell me about this audio file"},
#       7     {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
#       8 ])
# ---> 10 response = agent.invoke(
#      11     {"messages": [multimodal_question]}
#      12 )
#      14 print(response['messages'][-1].content)
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:3094, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3091 chunks: list[dict[str, Any] | Any] = []
#    3092 interrupts: list[Interrupt] = []
# -> 3094 for chunk in self.stream(
#    3095     input,
#    3096     config,
#    3097     context=context,
#    3098     stream_mode=["updates", "values"]
#    3099     if stream_mode == "values"
#    3100     else stream_mode,
#    3101     print_mode=print_mode,
#    3102     output_keys=output_keys,
#    3103     interrupt_before=interrupt_before,
#    3104     interrupt_after=interrupt_after,
#    3105     durability=durability,
#    3106     **kwargs,
#    3107 ):
#    3108     if stream_mode == "values":
#    3109         if len(chunk) == 2:
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:2669, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2667 for task in loop.match_cached_writes():
#    2668     loop.output_writes(task.id, task.writes, cached=True)
# -> 2669 for _ in runner.tick(
#    2670     [t for t in loop.tasks.values() if not t.writes],
#    2671     timeout=self.step_timeout,
#    2672     get_waiter=get_waiter,
#    2673     schedule_task=loop.accept_push,
#    2674 ):
#    2675     # emit output
#    2676     yield from _output(
#    2677         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2678     )
#    2679 loop.after_tick()
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_retry.py:71, in run_with_retry(task, retry_policy, configurable)
#      69     task.writes.clear()
#      70     # run the task
# ---> 71     return task.proc.invoke(task.input, config)
#      72 except ParentCommand as exc:
#      73     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1261, in create_agent.<locals>.model_node(state, runtime)
#    1249 request = ModelRequest(
#    1250     model=model,
#    1251     tools=default_tools,
#    (...)   1257     runtime=runtime,
#    1258 )
#    1260 if wrap_model_call_handler is None:
# -> 1261     model_response = _execute_model_sync(request)
#    1262     return _build_commands(model_response)
#    1264 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1233, in create_agent.<locals>._execute_model_sync(request)
#    1230 if request.system_message:
#    1231     messages = [request.system_message, *messages]
# -> 1233 output = model_.invoke(messages)
#    1234 if name:
#    1235     output.name = name
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:5695, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5688 @override
#    5689 def invoke(
#    5690     self,
#    (...)   5693     **kwargs: Any | None,
#    5694 ) -> Output:
# -> 5695     return self.bound.invoke(
#    5696         input,
#    5697         self._merge_configs(config),
#    5698         **{**self.kwargs, **kwargs},
#    5699     )
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1185, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1176 @override
#    1177 def generate_prompt(
#    1178     self,
#    (...)   1182     **kwargs: Any,
#    1183 ) -> LLMResult:
#    1184     prompt_messages = [p.to_messages() for p in prompts]
# -> 1185     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:995, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     992 for i, m in enumerate(input_messages):
#     993     try:
#     994         results.append(
# --> 995             self._generate_with_cache(
#     996                 m,
#     997                 stop=stop,
#     998                 run_manager=run_managers[i] if run_managers else None,
#     999                 **kwargs,
#    1000             )
#    1001         )
#    1002     except BaseException as e:
#    1003         if run_managers:
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1297, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1295     result = generate_from_stream(iter(chunks))
#    1296 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1297     result = self._generate(
#    1298         messages, stop=stop, run_manager=run_manager, **kwargs
#    1299     )
#    1300 else:
#    1301     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1473, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1471     _handle_openai_bad_request(e)
#    1472 except openai.APIError as e:
# -> 1473     _handle_openai_api_error(e)
#    1474 except Exception as e:
#    1475     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1468, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1461         return _construct_lc_result_from_responses_api(
#    1462             response,
#    1463             schema=original_schema_obj,
#    1464             metadata=generation_info,
#    1465             output_version=self.output_version,
#    1466         )
#    1467     else:
# -> 1468         raw_response = self.client.with_raw_response.create(**payload)
#    1469         response = raw_response.parse()
#    1470 except openai.BadRequestError as e:
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Developer/langchain-course/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: your_ope************here. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# During task with name 'model' and id '10bed254-1f3d-9b5c-224a-1864fe9ba6af'
