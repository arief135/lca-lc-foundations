# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 2.4 Wedding Planner
# In this lab you will build a multi-agent wedding planner.
#
# > Note: This lab has been updated since filming to make the agent performance more robust to errors and to limit run time. In particular: 1) added error handling for MCP failures, 2) limited the number of searches. It's worth noting that, where possible, tool errors should be returned to the agent rather than failing so that the agent can adjust its invocation and try again.

# %% [markdown]
# ## Setup Tools

# %%
import asyncio

from langchain_mcp_adapters.client import MultiServerMCPClient
from mcp.shared.exceptions import McpError
from mcp.types import CallToolResult, TextContent

RETRYABLE_MCP_CODES = {-32603}

class RetryMCPInterceptor:
    """Intercept MCP tool calls: retry transient failures, surface all errors gracefully.

    - Retryable McpError codes (e.g. -32603): retry with exponential backoff.
    - Non-retryable McpError codes (e.g. -32602): return error message immediately.
    - Any other exception (fetch failed, network errors, etc.): retry then return error message.
    """

    def __init__(self, max_retries: int = 3):
        self.max_retries = max_retries

    async def __call__(self, request, handler):
        last_error = None
        for attempt in range(self.max_retries):
            try:
                return await handler(request)
            except McpError as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(code {exc.error.code}, attempt {attempt+1}/{self.max_retries}): {exc}")
                if exc.error.code not in RETRYABLE_MCP_CODES:
                    return CallToolResult(
                        content=[TextContent(type="text", text=f"Tool call failed (non-retryable): {exc}")],
                        isError=False,
                    )
            except Exception as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(attempt {attempt+1}/{self.max_retries}): {exc}")

            if attempt < self.max_retries - 1:
                await asyncio.sleep(2 ** attempt)

        print(f"[MCP interceptor] all {self.max_retries} retries exhausted for {request.name}")
        return CallToolResult(
            content=[TextContent(type="text", text=f"Tool call failed after {self.max_retries} attempts: {last_error}")],
            isError=False,
        )

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    },
    tool_interceptors=[RetryMCPInterceptor()],
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str, search_number: int, max_search_number: int) -> Dict[str, Any]:
    """Search the web for information. You must track your search count by providing
    search_number (starting at 1) and max_search_number on every call.
    Queries must use only plain text characters. Do not use accented or special characters     
      (e.g., use 'capacite' instead of 'capacité').
    """
    if search_number > max_search_number:
        return {"message": "Search limit reached. Please summarize your findings and provide your final answer."}
    try:
        return tavily_client.search(query)
    except Exception as e:
        return {"error": str(e)}

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="qwen3.5:4b")

# from langchain_google_genai import ChatGoogleGenerativeAI

# model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model=model,
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    If the MCP tool fails, returns malformed output, or does not give you usable flight results, try the tool again.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model=model,
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options. 
    You have a suggested limit of 12 web searches. Count every web_search call you make.
    After 12 searches, you should stop searching and summarize the best options you have
    found so far.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model=model,
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.

    This is a SQLite database. Before writing any data queries, first discover the schema.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre. 
    This tool must be called alone, without any other tool calls. It must complete and return to make,
    the information available to other tools."""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model=model,
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. 
    First find all the information you need to update the state. When you have the information, update the state.
    Once that has completed and returned, you can delegate the tasks 
    to your specialists for flights, venues, and playlists.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
    },
    config={"tags": ["WP"], "recursion_limit": 40},  #tag traces to make them easy to find in Langsmith. Increase number of steps the agent can take to 40.
)
# Out:
# [MCP interceptor] McpError on search-flight (code -32602, attempt 1/3): MCP error -32602: MCP error -32602: Invalid arguments for tool search-flight: [
#   {
#     "code": "custom",
#     "message": "Dates must be in the future. Current date is 21/04/2026",
#     "path": [
#       "departureDate"
#     ]
#   }
# ]
# [MCP interceptor] McpError on search-flight (code -32602, attempt 1/3): MCP error -32602: MCP error -32602: Invalid arguments for tool search-flight: [
#   {
#     "code": "custom",
#     "message": "Dates must be in the future. Current date is 21/04/2026",
#     "path": [
#       "departureDate"
#     ]
#   }
# ]

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='c61eafe4-d751-4be1-acbb-b09389dbfb13'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen3.5:4b', 'created_at': '2026-04-21T01:35:34.290377Z', 'done': True, 'done_reason': 'stop', 'total_duration': 15222795167, 'load_duration': 3651729792, 'prompt_eval_count': 593, 'prompt_eval_duration': 2769287333, 'eval_count': 137, 'eval_duration': 8650808954, 'logprobs': None, 'model_name': 'qwen3.5:4b', 'model_provider': 'ollama'}, id='lc_run--019dadad-7418-7ff1-9e01-2aad9d4e18af-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'jazz'}, 'id': '9982b26c-23f8-4665-830a-7077cc002236', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 593, 'output_tokens': 137, 'total_tokens': 730}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='cb3cc0f9-ceac-45d9-b78c-7ea4462f1f91', tool_call_id='9982b26c-23f8-4665-830a-7077cc002236'),
#               AIMessage(content='Now that I have the necessary information (origin, destination, guest count, and genre), I will delegate the tasks to my specialists for flights, venues, and playlists.', additional_kwargs={}, response_metadata={'model': 'qwen3.5:4b', 'created_at': '2026-04-21T01:35:40.196959Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5890379875, 'load_duration': 118949125, 'prompt_eval_count': 680, 'prompt_eval_duration': 830701000, 'eval_count': 82, 'eval_duration': 4913135461, 'logprobs': None, 'model_name': 'qwen3.5:4b', 'model_provider': 'ollama'}, id='lc_run--019dadad-afa1-7ef2-bea2-6405b977b871-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': '7b18280d-421f-4caa-b271-e13561cb2ae2', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {}, 'id': '0617acb4-188c-49d6-8cc0-3028d7df97f9', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'c043d545-6877-441b-87b6-f68686331990', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 680, 'output_tokens': 82, 'total_tokens': 762}),
#               ToolMessage(content='# Flights from LHR to CDG on 2026-08-01\n\n| # | Price (EUR) | Departure (UTC) | Arrival (UTC) | Duration | Layover |\n|---|-------------|------------------|---------------|----------|---------|\n| 1 | 188 | 2026-08-01T18:20 | 2026-08-02T05:45 | 11.5 hrs | DUB |\n| 2 | 194 | 2026-08-01T19:50 | 2026-08-02T07:25 | 11.58 hrs | BCN |\n| 3 | 204 | 2026-08-01T20:10 | 2026-08-02T06:55 | 10.75 hrs | DUB |\n| 4 | 224 | 2026-08-01T13:20 | 2026-08-01T18:45 | 5.4 hrs | CPH |\n| 5 | 230 | 2026-08-01T05:30 | 2026-08-01T11:40 | 6.17 hrs | AMS |\n\n### Key Details:\n- **Lowest price:** €188 (Flight 1)\n- **Highest price:** €230 (Flight 5)\n- **Shortest flight:** 5.4 hours (Flight 4 - direct via Copenhagen)\n- **Longest flight:** 11.58 hours (Flight 2 - with Barcelona layover)\n\nAll 5 flights found depart from London Heathrow (LHR) to Paris Charles de Gaulle (CDG) on August 1, 2026, with varying prices ranging from €188 to €230. The cheapest option includes a Dublin layover, while the shortest flight has a Copenhagen stopover.', name='search_flights', id='df29458a-ebca-4eac-9166-8102179dc964', tool_call_id='7b18280d-421f-4caa-b271-e13561cb2ae2'),
#               ToolMessage(content='# Best Hotel Wedding Venues in Paris for 100 Guests\n\nBased on my research, here are the top venue options that meet your criteria of **lowest price**, **exact capacity of 100 guests**, and **highest reviews**:\n\n---\n\n## 🏆 TOP PICK: Five Star Champs-Elysees Hotel\n| Criterion | Details |\n|-----------|---------|\n| **Capacity** | 150 guests (cocktail reception) |\n| **Price** | 105 € per person (dinner menus) |\n| **Reviews** | Not specified in search results |\n| **Location** | Champs-Elysees, Paris |\n\n---\n\n## 🥈 RUNNER-UP: Renaissance Paris Arc de Triomphe Hotel\n| Criterion | Details |\n|-----------|---------|\n| **Capacity** | Not specified (can accommodate 100 guests) |\n| **Price** | €€€ (not specified) |\n| **Reviews** | 4.1 ★ (70 reviews) |\n| **Location** | Arc de Triomphe, Paris |\n\n---\n\n## 💰 BUDGET OPTION: Expedia Hotel Wedding Venues\n| Criterion | Details |\n|-----------|---------|\n| **Capacity** | Varies by hotel |\n| **Price** | From $122 per person (approx. 115 €) |\n| **Reviews** | 129 hotel venues reviewed |\n| **Location** | Paris, France |\n\n---\n\n## OTHER VIABLE OPTIONS\n\n| Venue | Capacity | Price | Reviews |\n|-------|----------|-------|---------|\n| Shangri-La Paris | 500 guests | N/A | Luxury |\n| Hotel de Crillon | Varies | N/A | Luxury |\n| Opera Garnier | Varies | N/A | Luxury |\n\n---\n\n## SUMMARY\n\n**Best Overall:** Five Star Champs-Elysees Hotel (105 €/person, 150 capacity)  \n**Most Review-Rated:** Renaissance Paris Arc de Triomphe (4.1/5 stars)  \n**Budget-Friendly:** Expedia venues starting at ~$122/person  \n\n**Note:** Paris hotel weddings typically offer better value than standalone venues for groups this size, as guests can utilize hotel rooms during their stay. Minimum stay requirements usually range from 2-3 nights for weddings.', name='search_venues', id='9dafb54f-405c-4d74-93b1-a39507dec208', tool_call_id='0617acb4-188c-49d6-8cc0-3028d7df97f9'),
#               ToolMessage(content='Based on the database data provided, this appears to be a music catalog system with the following key characteristics:\n\n## Database Overview\n\n**Genre:** All records are classified as **\'Jazz\'** with a uniform price of **$0.99**\n\n## Structure\nEach record contains:\n1. **ID** (unique identifier)\n2. **Title** (album/track name)\n3. **Duration** (in seconds)\n4. **Track #** (appears to be 1)\n5. **Catalog ID** (appears to be 2)\n6. **Artist/Composer** (noted in quotes for some entries)\n7. **Track ID**\n8. **Price** (0.99)\n9. **Genre** (\'Jazz\')\n\n## Sample Notable Entries\n- **Miles Davis - "Miles Ahead"**: 157 sec, 6,807,707 ID\n- **Dave Brubeck - "The Duke"**: 157 sec, 6,977,626 ID\n- **Gil Evans - "Blues For Pablo"**: 157 sec, 10,218,398 ID\n- **L\'Arc En Ciel De Miles - "L\'Arc En Ciel De Miles"**: 93 sec, 8,053,997 ID\n\nThis dataset appears to represent a jazz music collection spanning various eras and composers, with uniform pricing ($0.99) and consistent categorization.', name='suggest_playlist', id='3191a9bf-10bd-483b-89eb-f951f4828b80', tool_call_id='c043d545-6877-441b-87b6-f68686331990'),
#               AIMessage(content="Perfect! I've gathered all the information for your wedding in Paris. Here's your complete wedding coordination package:\n\n---\n\n## 📍 **Flight Recommendations**\n**Departure:** London Heathrow (LHR) → **Arrival:** Paris Charles de Gaulle (CDG)\n**Date:** August 1, 2026\n\n**Best Option:** Flight #1\n- **Price:** €188 per person (lowest)\n- **Route:** LHR → DUB (Dublin layover) → CDG\n- **Duration:** 11.5 hours\n- **Alternative:** Flight #4 at €224 is a direct flight via Copenhagen (5.4 hours) if you prefer shorter travel time\n\n---\n\n## 🏰 **Venue Recommendations**\n\n### 🏆 **TOP PICK: Five Star Champs-Elysees Hotel**\n- **Location:** Champs-Elysees, Paris (famous wedding location!)\n- **Capacity:** 150 guests (perfect for your 100)\n- **Price:** €105 per person\n- **Why:** Prime location, excellent value, and hotel wedding packages often include accommodations for guests\n\n### 💰 **Budget-Friendly: Expedia Hotel Venues**\n- **Price:** Starting at ~€115 per person\n- **Capacity:** Various options for 100 guests\n- **Best for:** Cost-conscious budget\n\n### ⭐ **Review-Rated: Renaissance Paris Arc de Triomphe**\n- **Rating:** 4.1/5 stars (70 reviews)\n- **Location:** Arc de Triomphe area\n- **Why:** Great reviews if you prefer hotel convenience over dedicated venue\n\n---\n\n## 🎷 **Jazz Playlist for Your Wedding**\nAll tracks are uniformly priced at $0.99 in our jazz catalog. Notable artists include:\n- Miles Davis\n- Dave Brubeck  \n- Gil Evans\n- And many more classic jazz composers\n\n---\n\n## 💰 **Estimated Total Cost (per guest)**\n- **Flights:** €188-230\n- **Venue/Dining:** €105-115\n- **Total:** €293-345 per guest\n\n**Note:** Paris hotel weddings typically require a 2-3 night minimum stay for guests.\n\nWould you like me to help you book any of these options or provide more details about specific venues or flights?", additional_kwargs={}, response_metadata={'model': 'qwen3.5:4b', 'created_at': '2026-04-21T02:03:36.072158Z', 'done': True, 'done_reason': 'stop', 'total_duration': 118575834000, 'load_duration': 113581083, 'prompt_eval_count': 2135, 'prompt_eval_duration': 17873379791, 'eval_count': 664, 'eval_duration': 100357369805, 'logprobs': None, 'model_name': 'qwen3.5:4b', 'model_provider': 'ollama'}, id='lc_run--019dadc5-89d2-7432-97c3-3a6cdf41a920-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2135, 'output_tokens': 664, 'total_tokens': 2799})],
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Perfect! I've gathered all the information for your wedding in Paris. Here's your complete wedding coordination package:
#
# ---
#
# ## 📍 **Flight Recommendations**
# **Departure:** London Heathrow (LHR) → **Arrival:** Paris Charles de Gaulle (CDG)
# **Date:** August 1, 2026
#
# **Best Option:** Flight #1
# - **Price:** €188 per person (lowest)
# - **Route:** LHR → DUB (Dublin layover) → CDG
# - **Duration:** 11.5 hours
# - **Alternative:** Flight #4 at €224 is a direct flight via Copenhagen (5.4 hours) if you prefer shorter travel time
#
# ---
#
# ## 🏰 **Venue Recommendations**
#
# ### 🏆 **TOP PICK: Five Star Champs-Elysees Hotel**
# - **Location:** Champs-Elysees, Paris (famous wedding location!)
# - **Capacity:** 150 guests (perfect for your 100)
# - **Price:** €105 per person
# - **Why:** Prime location, excellent value, and hotel wedding packages often include accommodations for guests
#
# ### 💰 **Budget-Friendly: Expedia Hotel Venues**
# - **Price:** Starting at ~€115 per person
# - **Capacity:** Various options for 100 guests
# - **Best for:** Cost-conscious budget
#
# ### ⭐ **Review-Rated: Renaissance Paris Arc de Triomphe**
# - **Rating:** 4.1/5 stars (70 reviews)
# - **Location:** Arc de Triomphe area
# - **Why:** Great reviews if you prefer hotel convenience over dedicated venue
#
# ---
#
# ## 🎷 **Jazz Playlist for Your Wedding**
# All tracks are uniformly priced at $0.99 in our jazz catalog. Notable artists include:
# - Miles Davis
# - Dave Brubeck
# - Gil Evans
# - And many more classic jazz composers
#
# ---
#
# ## 💰 **Estimated Total Cost (per guest)**
# - **Flights:** €188-230
# - **Venue/Dining:** €105-115
# - **Total:** €293-345 per guest
#
# **Note:** Paris hotel weddings typically require a 2-3 night minimum stay for guests.
#
# Would you like me to help you book any of these options or provide more details about specific venues or flights?

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
